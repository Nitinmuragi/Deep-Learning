# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical

# %%
text = "hello world this is an example of text generation using lstm"
chars = sorted(list(set(text)))

# %%
char_to_idx = {c: i for i, c in enumerate(chars)}
idx_to_char = {i: c for c, i in char_to_idx.items()}
encoded = np.array([char_to_idx[c] for c in text])

# %%
seq_length = 10
X, y = [], []

# %%
for i in range(len(encoded) - seq_length):
    X.append(encoded[i:i + seq_length])
    y.append(encoded[i + seq_length])

# %%
X = np.array(X)
y = to_categorical(y, num_classes=len(chars))

# %%
model = Sequential([
    Embedding(input_dim=len(chars), output_dim=64),
    LSTM(128),
    Dense(len(chars), activation='softmax')
])

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=50, batch_size=64, verbose=1)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.0400 - loss: 2.9456
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.1400 - loss: 2.9396
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.2400 - loss: 2.9335
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.2000 - loss: 2.9271
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.2200 - loss: 2.9202
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.2000 - loss: 2.9124
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.1800 - loss: 2.9034
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.1800 - loss: 2.8928
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.1800 - loss: 2.8801
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.1800 - loss: 2.8645
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.1800 - loss: 2.8454
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.1800 - loss: 2.8217
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.1800 - loss: 2.7926
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.1800 - loss: 2.7579
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.1800 - loss: 2.7199
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.1800 - loss: 2.6871
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.1800 - loss: 2.6806
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.1800 - loss: 2.6995
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.1800 - loss: 2.6953
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.1800 - loss: 2.6723
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.1800 - loss: 2.6505
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.1800 - loss: 2.6385
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.1800 - loss: 2.6346
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.1800 - loss: 2.6339
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.1800 - loss: 2.6331
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.1800 - loss: 2.6304
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.1800 - loss: 2.6253
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.1800 - loss: 2.6180
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - accuracy: 0.1800 - loss: 2.6092
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.1800 - loss: 2.6001
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.1800 - loss: 2.5915
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.1800 - loss: 2.5838
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.1800 - loss: 2.5763
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.1800 - loss: 2.5677
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.1800 - loss: 2.5568
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.1800 - loss: 2.5437
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.1800 - loss: 2.5294
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.1800 - loss: 2.5149
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.1800 - loss: 2.5000
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - accuracy: 0.2000 - loss: 2.4839
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.2200 - loss: 2.4656
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.2200 - loss: 2.4444
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.2400 - loss: 2.4202
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.2200 - loss: 2.3939
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.2200 - loss: 2.3664
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.2400 - loss: 2.3379
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.2600 - loss: 2.3082
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.2400 - loss: 2.2767
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.2600 - loss: 2.2441
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.2400 - loss: 2.2115

# %%
def generate_text(seed_text, next_chars=50):
    for _ in range(next_chars):
        encoded_input = np.array([char_to_idx[c] for c in seed_text[-seq_length:]])
        encoded_input = encoded_input.reshape(1, -1)
        predicted_probs = model.predict(encoded_input, verbose=0)[0]
        predicted_index = np.argmax(predicted_probs)
        predicted_char = idx_to_char[predicted_index]
        seed_text += predicted_char
    return seed_text

print(generate_text("hello worl", 50))
# Out:
# hello worl t    s eeeeeeeeottt  eeeaaeeeetteeeeeeeeeottt  ee

# %% [markdown]
# Title:
# Designing and developing a model for text or audio generation using LSTM / CNN
#
# Aim:
# To design and implement a deep learning model using Long Short-Term Memory (LSTM) or Convolutional Neural Network (CNN) architecture for generating coherent sequences of text or audio data.
#
# Objectives:
#
# Understand sequence generation principles in deep learning.
#
# Learn to preprocess text or audio datasets for training.
#
# Implement LSTM/CNN-based models for generation tasks.
#
# Train the model to generate new content based on learned patterns.
#
# Evaluate and analyze the quality of generated output.

# %%
import numpy as np

def step_function(x):
    return 1 if x >= 0 else 0

def train_perceptron(X, y, learning_rate=0.1, epochs=10):
    weights = np.zeros(X.shape[1])
    bias = 0

    for _ in range(epochs):
        for xi, target in zip(X, y):
            z = np.dot(xi, weights) + bias
            prediction = step_function(z)
            error = target - prediction
            weights += learning_rate * error * xi
            bias += learning_rate * error

    return weights, bias

# Input and Output for OR Gate
X = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([0, 1, 1, 1])

# Train the perceptron
weights, bias = train_perceptron(X, y)

print("Trained weights:", weights)
print("Trained bias:", bias)
print("\nTesting OR Gate:")
for xi in X:
    z = np.dot(xi, weights) + bias
    print(f"Input: {xi}, Output: {step_function(z)}")
# Out:
# Trained weights: [0.1 0.1]
# Trained bias: -0.1
#
# Testing OR Gate:
# Input: [0 0], Output: 0
# Input: [0 1], Output: 1
# Input: [1 0], Output: 1
# Input: [1 1], Output: 1

# %% [markdown]
# Title:
# Developing a simple Perceptron (Single Layer Neural Network)
#
# Aim:
# To implement and understand the working of a simple Perceptron (Single Layer Network) for binary classification tasks.
#
# Objectives:
#
# Understand the architecture of a Perceptron.
#
# Implement a Perceptron model in Python using NumPy or TensorFlow.
#
# Train the model using a dataset and test its performance.
#
# Visualize and interpret the output of the Perceptron.
#
# Learn how Perceptrons form the foundation of modern supervised learning algorithms.
#
# Prerequisites:
#
# Basic understanding of Python.
#
# Knowledge of machine learning concepts (especially supervised learning).
#
# Familiarity with NumPy and basic linear algebra.
#
# Conclusion:
# Perceptrons are foundational and form the simplest approach for data classification. Their basic architecture provides an understanding of how computational models learn simple decision boundaries. They are widely used as the basic learning unit in multilayer/advanced neural networks.
